# %%
#matplotlib
#john d hunter
#pip install matplotlib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.5.2

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 5, 3])
ypoints = np.array([2, 10, 5])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 10, 5])
plt.plot(ypoints, color = 'hotpink')
plt.show()
