# %%
import numpy as np 
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import seaborn as sns
import plotly.express as px

# %%
coffee = pd.read_csv("coffee.csv")
coffee.head()
# Out:
#                             Country      Coffee type    1990/91    1991/92  \
# 0                            Angola  Robusta/Arabica    1200000    1800000
# 1  Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                            Brazil  Arabica/Robusta  492000000  510000000
# 3                           Burundi  Arabica/Robusta     120000      96000
# 4                           Ecuador  Arabica/Robusta   21000000   21000000
#
#      1992/93    1993/94    1994/95    1995/96    1996/97    1997/98  ...  \
# 0    2100000    1200000    1500000     600000    1200000    2400000  ...
# 1    1650000    1710000    1770000    1830000    1890000    1950000  ...
# 2  534000000  546000000  558000000  606000000  660000000  690000000  ...
# 3     102000     114600     120000     120000     120000     120000  ...
# 4   21000000   21000000   21000000   21000000   18000000   18000000  ...
#
# ...

# %%
coffee.describe()
# Out:
#             1990/91       1991/92       1992/93       1993/94       1994/95  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.128278e+07  2.206701e+07  2.285613e+07  2.301590e+07  2.330200e+07
# std    6.810062e+07  7.032839e+07  7.363077e+07  7.511769e+07  7.679945e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.800000e+05  1.800000e+05  1.800000e+05  2.400000e+05  2.400000e+05
# 50%    2.040000e+06  3.000000e+06  3.000000e+06  2.400000e+06  3.000000e+06
# 75%    1.299000e+07  1.671300e+07  1.650000e+07  1.731000e+07  1.650000e+07
# max    4.920000e+08  5.100000e+08  5.340000e+08  5.460000e+08  5.580000e+08
#
#             1995/96       1996/97       1997/98       1998/99       1999/00  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.465735e+07  2.565010e+07  2.647750e+07  2.739992e+07  2.808131e+07
# ...

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     55 non-null     object
#  1   Coffee type                 55 non-null     object
#  2   1990/91                     55 non-null     int64
#  3   1991/92                     55 non-null     int64
#  4   1992/93                     55 non-null     int64
#  5   1993/94                     55 non-null     int64
#  6   1994/95                     55 non-null     int64
#  7   1995/96                     55 non-null     int64
#  8   1996/97                     55 non-null     int64
#  9   1997/98                     55 non-null     int64
#  10  1998/99                     55 non-null     int64
#  11  1999/00                     55 non-null     int64
#  12  2000/01                     55 non-null     int64
# ...

# %%
top_consume = coffee.sort_values(by = "Total_domestic_consumption" , ascending=False).head(10)
top_consume[["Country","Total_domestic_consumption"]]
# Out:
#         Country  Total_domestic_consumption
# 2        Brazil                 27824700000
# 5     Indonesia                  4920480000
# 29     Ethiopia                  4536540000
# 41       Mexico                  3189660000
# 18  Philippines                  2807280000
# 23     Colombia                  2536776384
# 52    Venezuela                  2386067999
# 36        India                  2093460000
# 53     Viet Nam                  1920928320
# 48     Thailand                  1248600000

# %%
consume_plot = sns.barplot(x = 'Country' , y = 'Total_domestic_consumption' , data=top_consume)

# %%
c_prod = pd.read_csv("Cproduction.csv")
c_prod.head()
# Out:
#                             Country      Coffee type       1990/91  \
# 0                            Angola  Robusta/Arabica  3.000000e+06
# 1  Bolivia (Plurinational State of)          Arabica  7.380000e+06
# 2                            Brazil  Arabica/Robusta  1.637160e+09
# 3                           Burundi  Arabica/Robusta  2.922000e+07
# 4                           Ecuador  Arabica/Robusta  9.024000e+07
#
#         1991/92       1992/93       1993/94       1994/95       1995/96  \
# 0  4.740000e+06  4.680000e+06  1.980000e+06  4.620000e+06  3.720000e+06
# 1  6.240000e+06  7.200000e+06  3.060000e+06  7.020000e+06  8.520000e+06
# 2  1.637580e+09  2.076180e+09  1.690020e+09  1.691520e+09  1.083600e+09
# 3  4.002000e+07  3.720000e+07  2.358000e+07  3.984000e+07  2.604000e+07
# 4  1.274400e+08  7.110000e+07  1.241400e+08  1.425600e+08  1.132800e+08
#
#         1996/97       1997/98  ...       2011/12       2012/13       2013/14  \
# ...

# %%
top_prod = c_prod.sort_values(by = "Total_production" , ascending = False).head(10)
top_prod[["Country", "Total_production"]]
# Out:
#       Country  Total_production
# 2      Brazil      7.508298e+10
# 53   Viet Nam      2.880318e+10
# 23   Colombia      2.159862e+10
# 5   Indonesia      1.540488e+10
# 29   Ethiopia      8.669520e+09
# 36      India      8.222220e+09
# 41     Mexico      7.853520e+09
# 32  Guatemala      7.020540e+09
# 35   Honduras      6.672720e+09
# 51     Uganda      5.919480e+09

# %%
produce_plot = sns.barplot(x = "Country", y = "Total_production", data = top_prod)

# %%
production_df = transpose_data(top_prod, 'Total_production', 'Coffee type')
production_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5216\886673921.py in <module>
# ----> 1 production_df = transpose_data(top_prod, 'Total_production', 'Coffee type')
#       2 production_df
#
# NameError: name 'transpose_data' is not defined
